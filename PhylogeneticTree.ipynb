# %%
from phylogenetic import executePhylogeneticTree

# %%
fileName = 'example.ft'

# %%
executePhylogeneticTree(fileName)
# Out:
# {'>gi|87137207|gb|DQ362940.1||lap=123,lng=123\n': '...', '>gi|87137205|gb|DQ362939.1||lat=123,lng=123\n': '...', '>gi|374432978|gb|JQ413400.1||lat=123,lng=123\n': '...'}
